# %% [markdown]
# Реализовать следующие требования к системе доступа:
# 1. ~~Доступ к ресурсам приложения должен предоставляться только предварительно зарегистрированным (учтённым) пользователям.~~
# 2. ~~Авторизация пользователя должна производиться только при положительном результате аутентификации.~~
# 3. Должно обеспечиваться блокирование учётной записи пользователя после следующих подряд трёх или задаваемого администратором количества неудачных попыток аутентификации (но не более 10-ти), регистрация факта и причины блокировки в журнале аудита.
# 4. ~~Параметрами событий, подлежащими обязательной регистрации, являются:~~
#     - ~~дата и время события~~;
#     - ~~идентификатор пользователя программного продукта~~;
#     - ~~идентификатор пользователя операционной системы и/или идентификатор (адрес) рабочей станции пользователя.~~
# 5. Событиями, подлежащими обязательной регистрации являются:
#     - ~~запуск и останов системы;~~
#     - ~~доступ (вход и выход) пользователей к приложению;~~
#     - ~~попытки неудачного (несанкционированного) доступа пользователей;~~
#     - изменение настроек регистрации событий в журнале аудита;
#     - выгрузка (архивирование) его содержимого и чистка журнала;
#     - операции пользователя с обрабатываемыми данными;
#     - создание, изменение и удаление учётных записей пользователей.
# 6. ~~Должна быть обеспечена фильтрация и сортировка данных журнала аудита (в том числе архивированных) по любому из его полей, а также возможность задания граничных значений для параметров даты и времени.~~
# 7. ~~Система должна выполнять периодическое архивирование зарегистрированной информации из журнала аудита в файл и удаление архивированных записей.~~
# 8. Должно быть обеспечено блокирование сеанса доступа в информационную систему после установленного времени бездействия (неактивности) пользователя или по его запросу.
# 9. ~~Должна быть обеспечена возможность настройки параметров системы безопасности: установка количества неудачных попыток для блокировки, время блокировки учетный записи, время простоя для блокировки сеанса доступа.~~
